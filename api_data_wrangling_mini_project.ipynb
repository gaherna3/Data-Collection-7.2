# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'P3jKP_2JK698TF1rhpru'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/ ).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url = 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X/'
params = dict(start_date='2017-01-01',end_date = '2017-01-02',order = 'asc',api_key=API_KEY)
r = requests.get(url, params)

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
r.json()
# Out:
# {'dataset': {'id': 10095370,
#   'dataset_code': 'AFX_X',
#   'database_code': 'FSE',
#   'name': 'Carl Zeiss Meditec (AFX_X)',
#   'description': 'Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704',
#   'refreshed_at': '2020-12-01T14:48:09.907Z',
#   'newest_available_date': '2020-12-01',
#   'oldest_available_date': '2000-06-07',
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Change',
#    'Traded Volume',
#    'Turnover',
#    'Last Price of the Day',
#    'Daily Traded Units',
#    'Daily Turnover'],
#   'frequency': 'daily',
#   'type': 'Time Series',
#   'premium': False,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '2017-01-01',
#   'end_date': '2017-01-02',
#   'data': [['2017-01-02',
#     34.99,
#     35.94,
#     34.99,
#     35.8,
#     None,
#     44700.0,
#     1590561.0,
#     None,
#     None,
# ...

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
params= dict(start_date='2017-01-01',end_date = '2017-12-31',order = 'asc',api_key=API_KEY)
r = requests.get(url, params)
json_data = r.json()

for k in json_data.keys():
    print(k + ': ',json_data[k])
# Out:
# dataset:  {'id': 10095370, 'dataset_code': 'AFX_X', 'database_code': 'FSE', 'name': 'Carl Zeiss Meditec (AFX_X)', 'description': 'Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704', 'refreshed_at': '2020-12-01T14:48:09.907Z', 'newest_available_date': '2020-12-01', 'oldest_available_date': '2000-06-07', 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover'], 'frequency': 'daily', 'type': 'Time Series', 'premium': False, 'limit': None, 'transform': None, 'column_index': None, 'start_date': '2017-01-01', 'end_date': '2017-12-31', 'data': [['2017-01-02', 34.99, 35.94, 34.99, 35.8, None, 44700.0, 1590561.0, None, None, None], ['2017-01-03', 35.9, 35.93, 35.34, 35.48, None, 70618.0, 2515473.0, None, None, None], ['2017-01-04', 35.48, 35.51, 34.75, 35.19, None, 54408.0, 1906810.0, None, None, None],
# ...

# %%
print(json_data.keys())
print(json_data['dataset']['column_names'])
print(json_data['dataset']['data'])
# Out:
# dict_keys(['dataset'])
# ['Date', 'Open', 'High', 'Low', 'Close', 'Change', 'Traded Volume', 'Turnover', 'Last Price of the Day', 'Daily Traded Units', 'Daily Turnover']
# ...

# %%
big_list= json_data['dataset']['data']

# %%
print(big_list)
# Out:
# [['2017-01-02', 34.99, 35.94, 34.99, 35.8, None, 44700.0, 1590561.0, None, None, None], ['2017-01-03', 35.9, 35.93, 35.34, 35.48, None, 70618.0, 2515473.0, None, None, None], ['2017-01-04', 35.48, 35.51, 34.75, 35.19, None, 54408.0, 1906810.0, None, None, None], ['2017-01-05', 35.02, 35.2, 34.73, 35.06, None, 48412.0, 1692326.0, None, None, None], ['2017-01-06', 34.91, 35.21, 34.91, 35.04, None, 27507.0, 964046.0, None, None, None], ['2017-01-09', 35.29, 35.35, 34.43, 34.67, None, 62225.0, 2157182.0, None, None, None], ['2017-01-10', 34.8, 34.98, 34.46, 34.91, None, 43976.0, 1528055.0, None, None, None], ['2017-01-11', 34.95, 36.0, 34.84, 35.42, None, 123530.0, 4369079.0, None, None, None], ['2017-01-12', 35.38, 35.38, 34.31, 34.9, None, 163860.0, 5703427.0, None, None, None], ['2017-01-13', 34.98, 34.98, 34.6, 34.85, None, 59367.0, 2065534.0, None, None, None], ['2017-01-16', 34.85, 35.24, 34.56, 35.07, None, 47879.0, 1678679.0, None, None, None], ['2017-01-17', 35.06, 35.19, 34.79,
# ...

# %%
dates = []
Open = []
for key in big_list:
    dates.append(key[0])
    Open.append(key[1])
    
yearly_min = min(filter(lambda x: x is not None, Open))
yearly_max = max(filter(lambda x: x is not None, Open))

print('The 52 week minimum is',yearly_min)
print('The 52 week minimum is',yearly_max)
# Out:
# The 52 week minimum is 34.0
# The 52 week minimum is 53.11

# %%
dates_open = [(x,y) for x in dates for y in Open]
print(dates_open)
# Out:
# [('2017-01-02', 34.99), ('2017-01-02', 35.9), ('2017-01-02', 35.48), ('2017-01-02', 35.02), ('2017-01-02', 34.91), ('2017-01-02', 35.29), ('2017-01-02', 34.8), ('2017-01-02', 34.95), ('2017-01-02', 35.38), ('2017-01-02', 34.98), ('2017-01-02', 34.85), ('2017-01-02', 35.06), ('2017-01-02', 35.04), ('2017-01-02', 35.04), ('2017-01-02', 34.54), ('2017-01-02', 34.04), ('2017-01-02', 34.0), ('2017-01-02', 34.42), ('2017-01-02', 35.07), ('2017-01-02', 34.83), ('2017-01-02', 35.38), ('2017-01-02', 35.24), ('2017-01-02', 34.75), ('2017-01-02', 35.95), ('2017-01-02', 36.02), ('2017-01-02', 36.06), ('2017-01-02', 35.56), ('2017-01-02', 35.98), ('2017-01-02', 36.2), ('2017-01-02', 36.65), ('2017-01-02', 37.37), ('2017-01-02', 38.81), ('2017-01-02', 38.5), ('2017-01-02', 38.8), ('2017-01-02', 38.8), ('2017-01-02', 39.25), ('2017-01-02', 38.85), ('2017-01-02', 39.6), ('2017-01-02', 39.72), ('2017-01-02', 39.77), ('2017-01-02', 39.75), ('2017-01-02', 40.38), ('2017-01-02', 41.19), ('2017-01-02', 4
# ...

# %%
daily_diff_list = []
for key in big_list:
    difference = abs(key[2] - key[3])
    daily_diff_list.append(difference)

max_daily_diff = max(daily_diff_list)    
print('The maximum change in a day is',round(max_daily_diff,2))
# Out:
# The maximum change in a day is 2.81

# %%
closing_list = []
for x in big_list:
    closing_list.append(x[3])

diff = [abs(closing_list[i+1] - closing_list[i]) for i in range(len(closing_list)-1)]
max_diff = max(diff)
print('The maximum change between days is',round(max_diff,2))
# Out:
# The maximum change between days is 3.44

# %%
vol_list = []
for x in big_list:
    vol_list.append(x[6])

def Average(vol_list):
    return sum(vol_list) / len(vol_list)

avg_vol = Average(vol_list)
print('The average daily volume for 2017 is',round(avg_vol,2))
# Out:
# The average daily volume for 2017 is 89124.34
